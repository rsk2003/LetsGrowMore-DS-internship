# %% [markdown]
# #LetsGrowMore Data Science Internship
# task4

# %% [markdown]
# ###name:Rehan Hudewale
# ###Data Science Problem statement-Image to Pencil Sketch with Python
# ###Reference-https://thecleverprogrammer.com/2020/09/30/pencil-sketch-with-python/
# ###IDE used:colab

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread("/content/flower.jpg")
original_image =cv2.resize(image, (700, 500))
cv2_imshow(original_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7F90518BD900>

# %% [markdown]
# Convert the RBG image to grayscale image

# %%
gray_scale_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F90518BC520>

# %% [markdown]
# Inverted the grayscale image

# %%
inverted_gray_scale_image = cv2.bitwise_not(gray_scale_image)
cv2_imshow(inverted_gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F90518BE170>

# %% [markdown]
# Apply a Guassian Blur

# %%
inverted_blurry_image = cv2.GaussianBlur(inverted_gray_scale_image, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(inverted_blurry_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F901E3B7250>

# %% [markdown]
# Mixing the gray scale image with inverted blurry image

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_pencil_sketch_image = dodgeV2(gray_scale_image,inverted_blurry_image)

cv2_imshow(final_pencil_sketch_image )
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F905256FCA0>

# %% [markdown]
# Original image and pancil sketch image

# %%
cv2_imshow(original_image)

cv2_imshow(final_pencil_sketch_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7F90518BDFC0>
# <PIL.Image.Image image mode=L size=700x500 at 0x7F90518BD5D0>
